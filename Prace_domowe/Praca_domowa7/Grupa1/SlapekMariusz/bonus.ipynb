# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import FastICA

# %% [markdown]
# ## Read data

# %%
data = pd.read_csv('../../signals.tsv', index_col=0, sep='\t')

# %% [markdown]
# ## Data info

# %%
data
# Out:
#        signal1   signal2   signal3   signal4
# time
# 0     0.493428  0.078710 -1.314636  1.193460
# 1     0.524618  0.791259 -1.321386 -0.075256
# 2    -0.024396  1.064251 -1.582284  0.785229
# 3     0.219586  1.007421 -1.481651  0.193773
# 4     0.426865  0.943133 -1.521795 -0.433458
# ...        ...       ...       ...       ...
# 9995 -0.448773 -1.111182  1.695837 -0.249654
# 9996 -1.017297 -1.054893  1.696765  0.547200
# 9997 -0.189845 -0.915049  1.544527  0.000046
# 9998 -0.563954 -0.785451  1.825540 -0.775807
# 9999  0.159883 -0.651097 -1.569233 -0.651786
#
# [10000 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
# signal1    10000 non-null float64
# signal2    10000 non-null float64
# signal3    10000 non-null float64
# signal4    10000 non-null float64
# dtypes: float64(4)
# memory usage: 390.6 KB

# %% [markdown]
# ## Function

# %%
def plot_data(data):
    fig, ax = plt.subplots(2, 2, figsize=(10, 4))
    ax[0, 0].plot(data.index, data.iloc[:, 0])
    ax[0, 1].plot(data.index, data.iloc[:, 1])
    ax[1, 0].plot(data.index, data.iloc[:, 2])
    ax[1, 1].plot(data.index, data.iloc[:, 3])

# %% [markdown]
# ## Plot data

# %%
plot_data(data)

# %% [markdown]
# ## ICA - Independent Component Analysis

# %%
ica = FastICA(n_components=4, random_state=123)
out = ica.fit_transform(data)
signals = pd.DataFrame(out)

# %%
plot_data(signals)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Jak widzimy dzięki zastosowaniu ICA znaleźliśmy jak wyglądały początkowe sygnały.
